# %%
import cv2
import numpy as np
import pandas as pd
from IPython.display import Image
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
img = cv2.imread('/Users/anilthapa/computer-vision/Anil_00.jpg', 0)
img
# Out:
# array([[229, 223, 221, ..., 221, 221, 221],
#        [224, 220, 220, ..., 221, 221, 221],
#        [223, 221, 219, ..., 221, 221, 221],
#        ...,
#        [ 62,  63,  66, ...,  67,  68,  68],
#        [ 61,  64,  66, ...,  68,  69,  68],
#        [ 64,  66,  68, ...,  67,  68,  68]], dtype=uint8)

# %%
img.shape
# Out:
# (600, 600, 3)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(img, cmap='gray')
